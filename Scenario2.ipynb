# %%
import pandas as pd
import itertools
from gurobipy import *

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html
production = pd.read_excel("base_case_data.xlsx", header = 0, index_col=0, sheet_name = "production")

setup = pd.read_excel("base_case_data.xlsx", header = 0, index_col=0, sheet_name = "setup")

demand = pd.read_excel("base_case_data.xlsx", header = 0, index_col=0, sheet_name = "demand")

# %%
# set up decision variables
# reference: https://stackoverflow.com/questions/1953194/permutations-of-two-lists-in-python
# part1, part2, part3...
part_names = list(setup.columns)

# machine1, machine2, machine3...
machine_names = list(setup.index)

# Week1, Week2, Week3...
week_list = []
for i in range(12):
    week_list.append("Week" + str(i+1))

# %%
# variable list
var_list_per_week = []
for i in range(len(demand)):
    for r in itertools.product(machine_names, part_names):
        if setup.loc[r[0], r[1]] != 0:
            var_list_per_week.append("Week" + str(i+1) + "_" + r[0]+ "_" +r[1]) 
# var_list_per_week
inventory_variable_list = []
for w in week_list:
    for p in part_names:
        name = w+"_"+p
        inventory_variable_list.append(name)
# inventory_variable_list

# %%
# coefficient
setup_co = {}
for v in var_list_per_week:
    machine = v.split("_")[1]
    part = v.split("_")[2]
    setup_co[v] = setup.loc[machine, part]
# setup_co

# %%
# right constraints
cumulative_right_eq = {}
for i in demand.index[0:12]:
    for name in part_names:
        if name in cumulative_right_eq.keys():
            cumulative_right_eq[name] += demand.loc[i, name]
        else:
            cumulative_right_eq[name] = demand.loc[i, name]
# cumulative_right_eq

# demand for each week 
week_right_geq = {}
for i in range(12):
    week_demand = {}
    for name in part_names:
        week_demand[name] = demand.loc[i+1, name]
    week_right_geq["Week"+str(i+1)] = week_demand
# week_right_geq

# maximum regular working hours per week
regular_hour_right_leq = {}
for name in machine_names:
    regular_hour_right_leq[name] = 120
# constraint_right_eq

# maximum overtime hours per week
overtime_hour_right_leq = {}
for name in machine_names:
    overtime_hour_right_leq[name] = 48
    
# inventory constraint right hand side
inventory_right = {}
for w in week_list:
    part_dic = {}
    for p in part_names:
        part_dic[p] = 0
    inventory_right[w] = part_dic
# inventory_right

# %%
# Demand of each part: Done
cumulative_left_eq = {}
# example {"Part1":{"Machine1_Part1_Production":24, ...}}
for p in part_names:
    production_co = {}
    for v in var_list_per_week:
        machine = v.split("_")[1]
        part = v.split("_")[2]
        if part == p:
            production_co[v] = production.loc[machine, part]
        else:
            production_co[v] = 0
    cumulative_left_eq[p] = production_co
# cumulative_left_geq

week_left_geq = {}
# example: {"Week1:":{"Part1":{variable}, "Part2":{variable}}, "Week2": {"Part1":{variable}, "Part2":{variable}}}
for w in week_list:
    week_dic = {}
    for p in part_names:
        part_dic = {}
        for v in var_list_per_week:
            week = v.split("_")[0]
            machine = v.split("_")[1]
            part = v.split("_")[2]
            if week == w and part == p:
                part_dic[v] = production.loc[machine, part]
            else:
                part_dic[v] = 0
        week_dic[p] = part_dic
    week_left_geq[w] = week_dic


# setup time for each machine per week
time_left_s_leq = {}
for w in week_list:
    week_dic = {}
    for m in machine_names:
        setup_dic = {}
        for v in var_list_per_week:
            week = v.split("_")[0]
            machine = v.split("_")[1]
            part = v.split("_")[2]
            if machine == m and week == w:
                setup_dic[v] = setup.loc[machine, part]
            else:
                setup_dic[v] = 0
        week_dic[m] = setup_dic
    time_left_s_leq[w] = week_dic

# working hours for each machine
working_left_leq = {}
# example {"Machine1":{"Machine1_Part1_Production":24, ...}}
for w in week_list:
    week_dic = {}
    for m in machine_names:
        production_dic = {}
        for v in var_list_per_week:
            week = v.split("_")[0]
            machine = v.split("_")[1]
            part = v.split("_")[2]
            if  machine == m and week == w:
                production_dic[v] = 1
            else:
                production_dic[v] = 0
        week_dic[m] = production_dic
    working_left_leq[w] = week_dic
# working_right_leq
# week_left_geq
demand_left = {}
for i in range(12):
    week_demand = {}
    for name in part_names:
        week_demand[name] = demand.loc[i+1, name]
    demand_left["Week"+str(i+1)] = week_demand
# demand_left

# inventory left side
inventory_left = {}
for w in week_list:
    dic = {}
    for p in part_names:
        part_dic = {}
        for v in inventory_variable_list:
            week = v.split("_")[0]
            part = v.split("_")[1]
            if w == "Week1":
                if week == "Week1" and part == p:
                    part_dic[v] = 1
                else:
                    part_dic[v] = 0
            elif w == "Week12" and part == p:
                if week == "Week11":
                    part_dic[v] = -1
                else:
                    part_dic[v] = 0
            else:
                number = int(w[4:])
                if week == "Week"+str(number-1) and part == p:
                    part_dic[v] = -1 
                elif week == w and part == p:
                    part_dic[v] = 1
                else:
                    part_dic[v] = 0
        dic[p] = part_dic
    inventory_left[w] = dic
# inventory_left

# %%
m=Model()
# set up variables
regular_production_levels = m.addVars(var_list_per_week, name="regular")
overtime_production_levels = m.addVars(var_list_per_week, name="overtime")
setup_levels = m.addVars(var_list_per_week, name="setup", vtype = GRB.BINARY)
inventory_levels = m.addVars(inventory_variable_list, name="inventory") 

# constraint
# cumulative production: DONE
eq_constraints_set = m.addConstrs((quicksum(setup_levels[v]*cumulative_left_eq[p][v]*regular_production_levels[v] for v in var_list_per_week) + quicksum(setup_levels[v]*cumulative_left_eq[p][v]*overtime_production_levels[v] for v in var_list_per_week) 
                                           == cumulative_right_eq[p] for p in part_names ), name="eq_constraints"); 
   
# regular working hours per week: DONE
regular_leq = m.addConstrs((quicksum(working_left_leq[w][m][vp]*regular_production_levels[vp] for vp in var_list_per_week) + quicksum(time_left_s_leq[w][m][vs]*setup_levels[vs] for vs in var_list_per_week) 
                            <= regular_hour_right_leq[m] for m in machine_names for w in week_list), name="regular_leq");
    
# overtime working hours per week: DONE
overtime_leq = m.addConstrs((quicksum(working_left_leq[w][m][vp]*overtime_production_levels[vp] for vp in var_list_per_week)
                             <= overtime_hour_right_leq[m] for m in machine_names for w in week_list), name="overtime_leq");

# inventory constraint per week: DONE
production_per_week = {}
for w in week_list:
    week_dic = {}
    for p in part_names:
        week_dic[p] = quicksum(setup_levels[v]*week_left_geq[w][p][v]*regular_production_levels[v] for v in var_list_per_week) + quicksum(setup_levels[v]*week_left_geq[w][p][v]*overtime_production_levels[v] for v in var_list_per_week)
    production_per_week[w] = week_dic

# week1 constraint    
week1_constr = m.addConstrs((demand_left["Week1"][p] + quicksum(inventory_left["Week1"][p][i]*inventory_levels[i] for i in inventory_variable_list) - production_per_week["Week1"][p]
                             == 0 for p in part_names), name="week1_inventory");
# Out:
# Academic license - for non-commercial use only

# %%
# week2 - week 12 constraint
other_week_constr = m.addConstrs((demand_left[week_list[i+1]][p] + quicksum(inventory_left[week_list[i+1]][p][j]*inventory_levels[j] for j in inventory_variable_list) - production_per_week[week_list[i+1]][p]
                             == 0 for p in part_names for i in range(len(week_list)-1)), name="other_week_inventory");

# inventory >= 0
inventory_constr = m.addConstrs((inventory_levels[i]>= 0 for i in inventory_variable_list), name="positive_inventory");

# %%
# objective function: minimize total cost = regular labour + overtime labour + setup + inventory
obj = quicksum(100*regular_production_levels[vp] for vp in var_list_per_week) + quicksum(100*setup_levels[vs]*setup_co[vs] for vs in var_list_per_week) + quicksum(150*overtime_production_levels[vp] for vp in var_list_per_week) + quicksum(10*inventory_levels[i] for i in inventory_variable_list)
m.update()
# minimize objective
m.setObjective(obj, GRB.MINIMIZE)
m.update()
# optimize model
m.optimize()
overtime_hours =0
#reference URL:www.gurobi.com/documentation/8.1/quickstart_mac/py_reporting_results_attri.html
overtime_per_week = {}
for i in week_list:
    overtime_per_week[i] = 0
overtime_per_week

for v in m.getVars():
    if v.x != 0:
        name = v.varName
        n1 = name.split("[")[0]
        n2 = name.split("[")[-1][:-1]
        w = n2.split("_")[0]
        if n1 == "setup":
            value = setup_co[n2]*v.x
        elif n1 == "overtime":
            value = v.x
            overtime_hours += v.x
            overtime_per_week[w] += v.x
        else:
            # value = v.x*production_co[n2]
            value = v.x
        print('%s %g' % (v.varName, value))
print('Obj: %g' % m.objVal)
print('total overtime hours: %g' % overtime_hours)
for i in overtime_per_week.keys():
    print(i+ " total overtime hours:%g" % overtime_per_week[i])
# Out:
# Optimize a model with 180 rows, 420 columns and 420 nonzeros
# Model has 65 quadratic constraints
# Variable types: 300 continuous, 120 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+01, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [2e+03, 5e+04]
# Presolve removed 60 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 905 rows, 655 columns, 2630 nonzeros
# Variable types: 535 continuous, 120 integer (120 binary)
#
# Root relaxation: objective 8.572819e+05, 253 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 857281.939    0   82          - 857281.939      -     -    0s
# H    0     0                    916853.13020 857281.939  6.50%     -    0s
#      0     0 881336.018    0   90 916853.130 881336.018  3.87%     -    0s
#      0     0 881336.018    0   90 916853.130 881336.018  3.87%     -    0s
#      0     2 881336.018    0   90 916853.130 881336.018  3.87%     -    0s
# H   99    89                    907596.04562 885630.785  2.42%   5.0    0s
# H  109    88                    905972.71229 885630.785  2.25%   4.7    0s
# H  139    89                    899639.88844 886898.387  1.42%   4.4    0s
# H  180   105                    899382.10456 886898.387  1.39%   4.7    0s
# *  503   294              36    899294.83683 888937.261  1.15%   5.2    0s
# H  750   440                    899078.85365 897752.787  0.15%   5.3    0s
# H  781   416                    898866.03313 898859.599  0.00%   6.1    0s
#
# Cutting planes:
#   Gomory: 14
#   Cover: 16
#   Implied bound: 5
#   Projected implied bound: 35
#   MIR: 56
#   Flow cover: 48
#
# Explored 788 nodes (5229 simplex iterations) in 0.71 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 8: 898866 899079 899295 ... 916853
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.988660331335e+05, best bound 8.988660331335e+05, gap 0.0000%
# regular[Week1_Machine1_Part1] 49.4359
# regular[Week1_Machine1_Part4] 54.5641
# regular[Week1_Machine2_Part1] 110
# regular[Week1_Machine2_Part2] -2.09686e-13
# regular[Week1_Machine3_Part2] 110
# regular[Week1_Machine4_Part2] 41.3333
# regular[Week1_Machine4_Part3] 58.6667
# regular[Week1_Machine5_Part5] 93.3333
# regular[Week2_Machine1_Part4] 110.256
# regular[Week2_Machine2_Part1] 110
# regular[Week2_Machine3_Part2] 110
# regular[Week2_Machine4_Part3] 100
# regular[Week2_Machine5_Part5] 93.3333
# regular[Week3_Machine1_Part1] 14.2564
# regular[Week3_Machine1_Part4] 89.7436
# regular[Week3_Machine2_Part1] 110
# regular[Week3_Machine3_Part2] 110
# regular[Week3_Machine4_Part3] 106.667
# regular[Week3_Machine5_Part5] 100
# regular[Week4_Machine1_Part1] 28.75
# regular[Week4_Machine1_Part4] 75.25
# regular[Week4_Machine2_Part1] 110
# regular[Week4_Machine3_Part2] 110
# regular[Week4_Machine4_Part3] 100
# regular[Week4_Machine5_Part5] 93.3333
# regular[Week5_Machine1_Part4] 102.564
# regular[Week5_Machine2_Part1] 110
# regular[Week5_Machine3_Part2] 110
# regular[Week5_Machine4_Part3] 100
# regular[Week5_Machine5_Part5] 93.3333
# regular[Week6_Machine1_Part1] 6.5641
# regular[Week6_Machine1_Part4] 97.4359
# regular[Week6_Machine2_Part1] 110
# regular[Week6_Machine3_Part2] 110
# regular[Week6_Machine4_Part3] 106.667
# regular[Week6_Machine5_Part5] 83.3333
# regular[Week7_Machine1_Part1] 1.4359
# regular[Week7_Machine1_Part4] 102.564
# regular[Week7_Machine2_Part1] 110
# regular[Week7_Machine3_Part2] 110
# regular[Week7_Machine4_Part3] 100
# regular[Week7_Machine5_Part5] 83.3333
# regular[Week8_Machine1_Part4] 107.692
# regular[Week8_Machine2_Part1] 110
# regular[Week8_Machine3_Part2] 110
# regular[Week8_Machine4_Part2] 1.33333
# regular[Week8_Machine4_Part3] 98.6667
# regular[Week8_Machine5_Part5] 83.3333
# regular[Week9_Machine1_Part4] 112
# regular[Week9_Machine2_Part1] 110
# regular[Week9_Machine3_Part2] 75.3939
# regular[Week9_Machine4_Part2] 112
# regular[Week9_Machine5_Part5] 100
# regular[Week10_Machine1_Part4] 112
# regular[Week10_Machine2_Part1] 110
# regular[Week10_Machine3_Part2] 110
# regular[Week10_Machine4_Part2] 112
# regular[Week10_Machine5_Part5] 100
# regular[Week11_Machine1_Part4] 104
# regular[Week11_Machine2_Part1] 110
# regular[Week11_Machine3_Part2] 110
# regular[Week11_Machine4_Part3] 100
# regular[Week11_Machine5_Part5] 92
# regular[Week12_Machine1_Part4] 110.256
# regular[Week12_Machine2_Part1] 110
# regular[Week12_Machine3_Part2] 110
# regular[Week12_Machine4_Part3] 100
# regular[Week12_Machine5_Part5] 93.3333
# overtime[Week1_Machine1_Part1] -5.92967e-13
# overtime[Week1_Machine1_Part4] 48
# overtime[Week1_Machine2_Part1] 0.168498
# overtime[Week1_Machine3_Part2] 23.596
# overtime[Week1_Machine4_Part3] 48
# overtime[Week2_Machine2_Part1] 32.8571
# overtime[Week2_Machine3_Part2] 11.4747
# overtime[Week2_Machine4_Part2] 41.3333
# overtime[Week2_Machine4_Part3] 6.66667
# overtime[Week3_Machine1_Part1] 14.4936
# overtime[Week3_Machine3_Part2] 11.2121
# overtime[Week4_Machine1_Part4] 22.1859
# overtime[Week4_Machine3_Part2] 23.596
# overtime[Week4_Machine4_Part2] 41.3333
# overtime[Week4_Machine4_Part3] 6.66667
# overtime[Week5_Machine2_Part1] 32.8571
# overtime[Week5_Machine3_Part2] 23.596
# overtime[Week5_Machine4_Part2] 41.3333
# overtime[Week5_Machine4_Part3] 6.66667
# overtime[Week6_Machine1_Part1] 43.0192
# overtime[Week6_Machine3_Part2] 41.5152
# overtime[Week7_Machine1_Part1] 48
# overtime[Week7_Machine2_Part1] 0.168498
# overtime[Week7_Machine4_Part2] 35.5844
# overtime[Week7_Machine4_Part3] 1.33333
# overtime[Week8_Machine2_Part1] 47.1429
# overtime[Week8_Machine3_Part2] 38.5051
# overtime[Week8_Machine4_Part2] 48
# overtime[Week9_Machine1_Part4] 3.38462
# overtime[Week9_Machine2_Part1] 47.1429
# overtime[Week10_Machine1_Part4] 3.38462
# overtime[Week10_Machine2_Part1] 48
# overtime[Week10_Machine4_Part2] 7.25541
# overtime[Week10_Machine5_Part5] 7.20513
# overtime[Week11_Machine1_Part1] 44.3333
# overtime[Week11_Machine1_Part4] 3.66667
# overtime[Week11_Machine2_Part1] 48
# overtime[Week11_Machine3_Part2] 48
# overtime[Week11_Machine4_Part2] 14.6667
# overtime[Week11_Machine4_Part3] 33.3333
# overtime[Week11_Machine5_Part4] 20.5385
# overtime[Week11_Machine5_Part5] 27.4615
# overtime[Week12_Machine2_Part1] 32.8571
# overtime[Week12_Machine3_Part2] 11.4747
# overtime[Week12_Machine4_Part2] 41.3333
# overtime[Week12_Machine4_Part3] 6.66667
# setup[Week1_Machine1_Part1] 8
# setup[Week1_Machine1_Part4] 8
# setup[Week1_Machine2_Part1] 10
# setup[Week1_Machine3_Part2] 10
# setup[Week1_Machine4_Part2] 8
# setup[Week1_Machine4_Part3] 12
# setup[Week1_Machine5_Part5] 20
# setup[Week2_Machine1_Part4] 8
# setup[Week2_Machine2_Part1] 10
# setup[Week2_Machine3_Part2] 10
# setup[Week2_Machine4_Part2] 8
# setup[Week2_Machine4_Part3] 12
# setup[Week2_Machine5_Part5] 20
# setup[Week3_Machine1_Part1] 8
# setup[Week3_Machine1_Part4] 8
# setup[Week3_Machine2_Part1] 10
# setup[Week3_Machine3_Part2] 10
# setup[Week3_Machine4_Part3] 12
# setup[Week3_Machine5_Part5] 20
# setup[Week4_Machine1_Part1] 8
# setup[Week4_Machine1_Part4] 8
# setup[Week4_Machine2_Part1] 10
# setup[Week4_Machine3_Part2] 10
# setup[Week4_Machine4_Part2] 8
# setup[Week4_Machine4_Part3] 12
# setup[Week4_Machine5_Part5] 20
# setup[Week5_Machine1_Part4] 8
# setup[Week5_Machine2_Part1] 10
# setup[Week5_Machine3_Part2] 10
# setup[Week5_Machine4_Part2] 8
# setup[Week5_Machine4_Part3] 12
# setup[Week5_Machine5_Part5] 20
# setup[Week6_Machine1_Part1] 8
# setup[Week6_Machine1_Part4] 8
# setup[Week6_Machine2_Part1] 10
# setup[Week6_Machine3_Part2] 10
# setup[Week6_Machine4_Part3] 12
# setup[Week6_Machine5_Part5] 20
# setup[Week7_Machine1_Part1] 8
# setup[Week7_Machine1_Part4] 8
# setup[Week7_Machine2_Part1] 10
# setup[Week7_Machine3_Part2] 10
# setup[Week7_Machine4_Part2] 8
# setup[Week7_Machine4_Part3] 12
# setup[Week7_Machine5_Part5] 20
# setup[Week8_Machine1_Part4] 8
# setup[Week8_Machine2_Part1] 10
# setup[Week8_Machine3_Part2] 10
# setup[Week8_Machine4_Part2] 8
# setup[Week8_Machine4_Part3] 12
# setup[Week8_Machine5_Part5] 20
# setup[Week9_Machine1_Part4] 8
# setup[Week9_Machine2_Part1] 10
# setup[Week9_Machine3_Part2] 10
# setup[Week9_Machine4_Part2] 8
# setup[Week9_Machine5_Part5] 20
# setup[Week10_Machine1_Part4] 8
# setup[Week10_Machine2_Part1] 10
# setup[Week10_Machine3_Part2] 10
# setup[Week10_Machine4_Part2] 8
# setup[Week10_Machine5_Part5] 20
# setup[Week11_Machine1_Part1] 8
# setup[Week11_Machine1_Part4] 8
# setup[Week11_Machine2_Part1] 10
# setup[Week11_Machine3_Part2] 10
# setup[Week11_Machine4_Part2] 8
# setup[Week11_Machine4_Part3] 12
# setup[Week11_Machine5_Part4] 8
# setup[Week11_Machine5_Part5] 20
# setup[Week12_Machine1_Part4] 8
# setup[Week12_Machine2_Part1] 10
# setup[Week12_Machine3_Part2] 10
# setup[Week12_Machine4_Part2] 8
# setup[Week12_Machine4_Part3] 12
# setup[Week12_Machine5_Part5] 20
# inventory[Week10_Part1] 118
# inventory[Week10_Part2] 1110.67
# inventory[Week10_Part3] 2.27374e-13
# inventory[Week10_Part5] 216.154
# Obj: 898866
# total overtime hours: 1188.01
# Week1 total overtime hours:119.764
# Week2 total overtime hours:92.3319
# Week3 total overtime hours:25.7057
# Week4 total overtime hours:93.7819
# Week5 total overtime hours:104.453
# Week6 total overtime hours:84.5344
# Week7 total overtime hours:85.0862
# Week8 total overtime hours:133.648
# Week9 total overtime hours:50.5275
# Week10 total overtime hours:65.8452
# Week11 total overtime hours:240
# Week12 total overtime hours:92.3319

# %% [markdown]
# ## Comment
# If we set the cost for each inventory as 10 dollar, the optimal solution shows that some inventories left over from week10 to week11. The total cost is 898866 dollar for 12 weeks, and the total number of overtime is 1188.01 hours.

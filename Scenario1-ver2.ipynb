# %%
import pandas as pd
import itertools
from gurobipy import *

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html
production = pd.read_excel("base_case_data.xlsx", header = 0, index_col=0, sheet_name = "production")

setup = pd.read_excel("base_case_data.xlsx", header = 0, index_col=0, sheet_name = "setup")

demand = pd.read_excel("base_case_data.xlsx", header = 0, index_col=0, sheet_name = "demand")

# %%
# set up decision variables
# reference: https://stackoverflow.com/questions/1953194/permutations-of-two-lists-in-python
part_names = list(setup.columns)
machine_names = list(setup.index)

# this is the working time in a week
var_list = []
for r in itertools.product(machine_names, part_names):
    var_list.append(r[0]+ "_" +r[1]) 
# var_list

# %%
# cost contribution
regular_cost = {}
for v in var_list:
    first = v.split("_")[0]
    second = v.split("_")[1]
    regular_cost[v] = 100

overtime_cost = {}
for v in var_list:
    first = v.split("_")[0]
    second = v.split("_")[1]
    regular_cost[v] = 150

# %%
# create dictionary for objective coefficient
setup_co = {}
for v in var_list:
    first = v.split("_")[0]
    second = v.split("_")[1]
    setup_co[v] = setup.loc[first, second]

# %%
# maximum regular working hours per week
regular_hour_right_leq = {}
for name in machine_names:
    regular_hour_right_leq[name] = 120
# constraint_right_eq

# maximum overtime hours per week
overtime_hour_right_leq = {}
for name in machine_names:
    overtime_hour_right_leq[name] = 48

# %%
# Demand of each part
constraint_left_p_eq = {}
# example {"Part1":{"Machine1_Part1_Production":24, ...}}
for p in part_names:
    production_co = {}
    for v in var_list:
        first = v.split("_")[0]
        second = v.split("_")[1]
        if second ==p:
            production_co[v] = production.loc[first, second]
        else:
            production_co[v] = 0
    constraint_left_p_eq[p] = production_co
# constraint_left_p_eq

# setup time for each machine
constraint_left_s_leq = {}
# example {"Machine1":{"Machine1_Part1_Production":8, ...}}
for m in machine_names:
    setup_dic = {}
    for v in var_list:
        first = v.split("_")[0]
        second = v.split("_")[1]
        if first == m:
            setup_dic[v] = setup.loc[first, second]
        else:
            setup_dic[v] = 0
    constraint_left_s_leq[m] = setup_dic
    

# production time for each machine
constraint_left_p_leq = {}
# example {"Machine1":{"Machine1_Part1_Production":24, ...}}
for m in machine_names:
    production_dic = {}
    for v in var_list:
        first = v.split("_")[0]
        second = v.split("_")[1]
        if first == m:
            production_dic[v] = 1
        else:
            production_dic[v] = 0
    constraint_left_p_leq[m] = production_dic
# constraint_left_p_leq

# %%
def resolve_model(week):
    # set up constraints name
    # demand
    constraint_right_eq = {}
    for name in part_names:
        constraint_right_eq[name] = demand.loc[week, name]

    m=Model()
    # set up variables
    regular_production_levels = m.addVars(var_list, name="regular")
    overtime_production_levels = m.addVars(var_list, name="overtime")
    setup_levels = m.addVars(var_list, name="setup", vtype = GRB.BINARY)

    # constraint
    eq_constraints_set = m.addConstrs((quicksum(setup_levels[v]*constraint_left_p_eq[p][v]*regular_production_levels[v] for v in var_list) + quicksum(setup_levels[v]*constraint_left_p_eq[p][v]*overtime_production_levels[v] for v in var_list)
                                           == constraint_right_eq[p] for p in part_names ), name="eq_constraints"); 
    
    # regular working hours
    regular_leq = m.addConstrs((quicksum(constraint_left_p_leq[m][vp]*regular_production_levels[vp] for vp in var_list) + quicksum(constraint_left_s_leq[m][vs]*setup_levels[vs] for vs in var_list) 
                                           <= regular_hour_right_leq[m] for m in machine_names), name="regular_leq");
    
    # overtime working hours
    overtime_leq = m.addConstrs((quicksum(constraint_left_p_leq[m][vp]*overtime_production_levels[vp] for vp in var_list)
                                           <= overtime_hour_right_leq[m] for m in machine_names), name="overtime_leq");
    
    # positive constrait
#     regular_positive = m.addConstrs((regular_production_levels[vp] >= 0 for vp in var_list), name="regular_positive");
#     overtime_positive = m.addConstrs((overtime_production_levels[vp] >= 0 for vp in var_list), name="overtime_positive");
    
    # objective function for hours
    obj = quicksum(overtime_production_levels[vp] for vp in var_list)
    m.update()
    # minimize objective
    m.setObjective(obj, GRB.MINIMIZE)
    m.update()
    # optimize model
    m.optimize()
    #reference URL:www.gurobi.com/documentation/8.1/quickstart_mac/py_reporting_results_attri.html
    cost = 0
    regular_hours = 0
    for v in m.getVars():
        if v.x != 0:
            name = v.varName
            n1 = name.split("[")[0]
            n2 = name.split("[")[-1][:-1]
            if n1 == "setup":
                value = setup_co[n2]*v.x
                cost += setup_co[n2]*v.x*100
                regular_hours += setup_co[n2]*v.x
            elif n1 == "regular":
                value = v.x
                cost += 100*v.x
                regular_hours += v.x
            else:
                value = v.x
                cost += 150*v.x
            print('%s %g' % (v.varName, value))  

    print('Obj: %g' % m.ObjVal)
    print('total cost1: %g' % cost)
    print("regular hours: %g" % regular_hours)
    m.reset()

# %%
resolve_model(1)
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 1.120894e+02, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  112.08943    0    6          -  112.08943      -     -    0s
# H    0     0                     128.0767288  112.08943  12.5%     -    0s
# H    0     0                     119.7644578  112.08943  6.41%     -    0s
#      0     0  119.74547    0    1  119.76446  119.74547  0.02%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 1
#
# Explored 1 nodes (28 simplex iterations) in 0.09 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 119.764 128.077
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.197644577645e+02, best bound 1.197644577645e+02, gap 0.0000%
# regular[Machine1_Part1] 1.4359
# regular[Machine1_Part4] 102.564
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part2] 41.3333
# regular[Machine4_Part3] 58.6667
# regular[Machine5_Part5] 93.3333
# overtime[Machine1_Part1] 48
# overtime[Machine2_Part1] 0.168498
# overtime[Machine3_Part2] 23.596
# overtime[Machine4_Part3] 48
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# Obj: 119.764
# total cost1: 77298
# regular hours: 593.333

# %%
resolve_model(2)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 8.216657e+01, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   82.16657    0    6          -   82.16657      -     -    0s
# H    0     0                     102.8144911   82.16657  20.1%     -    0s
# H    0     0                      92.3318903   82.16657  11.0%     -    0s
#      0     0     cutoff    0        92.33189   92.33189  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#   Implied bound: 3
#   MIR: 1
#
# Explored 1 nodes (30 simplex iterations) in 0.07 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 92.3319 102.814
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.233189033189e+01, best bound 9.233189033189e+01, gap 0.0000%
# regular[Machine1_Part4] 110.256
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part2] 41.3333
# regular[Machine4_Part3] 58.6667
# regular[Machine5_Part5] 93.3333
# overtime[Machine2_Part1] 32.8571
# overtime[Machine3_Part2] 11.4747
# overtime[Machine4_Part3] 48
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# Obj: 92.3319
# total cost1: 73008.8
# regular hours: 591.59

# %%
resolve_model(3)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [2e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 2.392348e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   23.92348    0    3          -   23.92348      -     -    0s
# H    0     0                      32.7057110   23.92348  26.9%     -    0s
# H    0     0                      25.7057110   23.92348  6.93%     -    0s
#      0     0     cutoff    0        25.70571   25.70571  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 25.7057 32.7057
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.570571095571e+01, best bound 2.570571095571e+01, gap 0.0000%
# regular[Machine1_Part1] 28.75
# regular[Machine1_Part4] 75.25
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 106.667
# regular[Machine5_Part5] 100
# overtime[Machine1_Part4] 14.4936
# overtime[Machine3_Part2] 11.2121
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# Obj: 25.7057
# total cost1: 63722.5
# regular hours: 598.667

# %%
resolve_model(4)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 8.860615e+01, 18 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   88.60615    0    6          -   88.60615      -     -    0s
# H    0     0                     102.1151904   88.60615  13.2%     -    0s
# H    0     0                     100.7818570   88.60615  12.1%     -    0s
# *    0     0               0      93.7818570   93.78186  0.00%     -    0s
#
# Cutting planes:
#   Cover: 1
#   Implied bound: 1
#   MIR: 1
#   Flow cover: 1
#
# Explored 1 nodes (25 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 93.7819 100.782 102.115
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.378185703186e+01, best bound 9.378185703186e+01, gap 0.0000%
# regular[Machine1_Part1] 6.5641
# regular[Machine1_Part4] 97.4359
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part2] 41.3333
# regular[Machine4_Part3] 58.6667
# regular[Machine5_Part5] 93.3333
# overtime[Machine1_Part1] 22.1859
# overtime[Machine3_Part2] 23.596
# overtime[Machine4_Part3] 48
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# Obj: 93.7819
# total cost1: 73400.6
# regular hours: 593.333

# %%
resolve_model(5)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 9.198051e+01, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   91.98051    0    6          -   91.98051      -     -    0s
# H    0     0                     107.2433955   91.98051  14.2%     -    0s
# H    0     0                      98.9100622   91.98051  7.01%     -    0s
#      0     0     cutoff    0        98.91006   98.91006  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 2
#   Flow cover: 1
#
# Explored 1 nodes (25 simplex iterations) in 0.06 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 98.9101 107.243
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.891006216006e+01, best bound 9.891006216006e+01, gap 0.0000%
# regular[Machine1_Part1] 28.75
# regular[Machine1_Part4] 75.25
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part2] 41.3333
# regular[Machine4_Part3] 58.6667
# regular[Machine5_Part5] 93.3333
# overtime[Machine1_Part4] 27.3141
# overtime[Machine3_Part2] 23.596
# overtime[Machine4_Part3] 48
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# Obj: 98.9101
# total cost1: 74169.8
# regular hours: 593.333

# %%
resolve_model(6)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [2e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 6.901568e+01, 17 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.01568    0    5          -   69.01568      -     -    0s
# H    0     0                      83.6036464   69.01568  17.4%     -    0s
# H    0     0                      75.8677156   69.01568  9.03%     -    0s
#      0     0   72.60361    0    1   75.86772   72.60361  4.30%     -    0s
#      0     0     cutoff    0        75.86772   75.86772  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   MIR: 3
#   Flow cover: 1
#
# Explored 1 nodes (24 simplex iterations) in 0.07 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 75.8677 83.6036
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.586771561772e+01, best bound 7.586771561772e+01, gap 0.0000%
# regular[Machine1_Part1] 49.5833
# regular[Machine1_Part4] 54.4167
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 106.667
# regular[Machine5_Part4] 43.0192
# regular[Machine5_Part5] 48.9808
# overtime[Machine3_Part2] 41.5152
# overtime[Machine5_Part5] 34.3526
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part3] 12
# setup[Machine5_Part4] 8
# setup[Machine5_Part5] 20
# Obj: 75.8677
# total cost1: 71246.8
# regular hours: 598.667

# %%
resolve_model(7)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [2e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 6.873712e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   68.73712    0    3          -   68.73712      -     -    0s
# H    0     0                      76.3985181   68.73712  10.0%     -    0s
#      0     0     cutoff    0        76.39852   76.39852  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   MIR: 2
#   Flow cover: 3
#
# Explored 1 nodes (19 simplex iterations) in 0.05 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 76.3985
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.639851814852e+01, best bound 7.639851814852e+01, gap 0.0000%
# regular[Machine1_Part1] 49.5833
# regular[Machine1_Part4] 54.4167
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part2] 35.5844
# regular[Machine4_Part3] 64.4156
# regular[Machine5_Part4] 48.1474
# regular[Machine5_Part5] 43.8526
# overtime[Machine4_Part3] 36.9177
# overtime[Machine5_Part5] 39.4808
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part4] 8
# setup[Machine5_Part5] 20
# Obj: 76.3985
# total cost1: 71459.8
# regular hours: 600

# %%
resolve_model(8)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [2e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 1.114552e+02, 20 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  111.45518    0    5          -  111.45518      -     -    0s
# H    0     0                     129.7806915  111.45518  14.1%     -    0s
# H    0     0                     122.7806915  111.45518  9.22%     -    0s
#      0     0     cutoff    0       122.78069  122.78069  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 2
#   MIR: 2
#   Flow cover: 2
#
# Explored 1 nodes (26 simplex iterations) in 0.08 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 122.781 129.781
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.227806915307e+02, best bound 1.227806915307e+02, gap 0.0000%
# regular[Machine1_Part1] 41.25
# regular[Machine1_Part4] 62.75
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part2] 49.3333
# regular[Machine4_Part3] 50.6667
# regular[Machine5_Part4] 44.9423
# regular[Machine5_Part5] 47.0577
# overtime[Machine3_Part2] 38.5051
# overtime[Machine4_Part3] 48
# overtime[Machine5_Part5] 36.2756
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part4] 8
# setup[Machine5_Part5] 20
# Obj: 122.781
# total cost1: 78417.1
# regular hours: 600

# %%
resolve_model(9)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 1.267085e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.67085    0    6          -   12.67085      -     -    0s
# H    0     0                      48.6891608   12.67085  74.0%     -    0s
#      0     0   24.82422    0    8   48.68916   24.82422  49.0%     -    0s
#      0     0   25.82782    0    1   48.68916   25.82782  47.0%     -    0s
#      0     0   25.82782    0    1   48.68916   25.82782  47.0%     -    0s
# H    0     0                      43.9957265   25.82782  41.3%     -    0s
# H    0     0                      31.0782868   25.82782  16.9%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 2
#   Implied bound: 4
#   Flow cover: 2
#
# Explored 1 nodes (29 simplex iterations) in 0.10 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 31.0783 43.9957 48.6892
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.107828679257e+01, best bound 3.107828679257e+01, gap 0.0000%
# regular[Machine1_Part1] 112
# regular[Machine2_Part1] 29.1429
# regular[Machine2_Part2] 72.8571
# regular[Machine3_Part5] 96
# regular[Machine4_Part2] 112
# regular[Machine5_Part4] 112
# overtime[Machine3_Part5] 15.1111
# overtime[Machine4_Part2] 12.5826
# overtime[Machine5_Part4] 3.38462
# overtime[Machine5_Part5] 4.39589e-13
# setup[Machine1_Part1] 8
# setup[Machine2_Part1] 10
# setup[Machine2_Part2] 8
# setup[Machine3_Part5] 24
# setup[Machine4_Part2] 8
# setup[Machine5_Part4] 8
# Obj: 31.0783
# total cost1: 64661.7
# regular hours: 600

# %%
resolve_model(10)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 0.000000e+00, 13 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    6          -    0.00000      -     -    0s
# H    0     0                      23.9088689    0.00000   100%     -    0s
#      0     0    5.45800    0    5   23.90887    5.45800  77.2%     -    0s
#      0     0    6.27455    0    5   23.90887    6.27455  73.8%     -    0s
#      0     0   12.24476    0    3   23.90887   12.24476  48.8%     -    0s
# H    0     0                      18.4957265   12.24476  33.8%     -    0s
# H    0     0                      15.1111111   12.24476  19.0%     -    0s
#      0     0     cutoff    0        15.11111   15.11111  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Implied bound: 3
#   MIR: 1
#   Flow cover: 4
#
# Explored 1 nodes (37 simplex iterations) in 0.08 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 15.1111 18.4957 23.9089
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.511111111111e+01, best bound 1.511111111111e+01, gap 0.0000%
# regular[Machine1_Part1] 97.7924
# regular[Machine1_Part4] 6.20758
# regular[Machine2_Part1] 40.6182
# regular[Machine2_Part2] 61.3818
# regular[Machine3_Part5] 96
# regular[Machine4_Part2] 112
# regular[Machine5_Part4] 109.177
# regular[Machine5_Part5] 4.39589e-13
# overtime[Machine3_Part5] 15.1111
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine2_Part2] 8
# setup[Machine3_Part5] 24
# setup[Machine4_Part2] 8
# setup[Machine5_Part4] 8
# Obj: 15.1111
# total cost1: 61984.4
# regular hours: 597.177

# %%
resolve_model(11)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [4e+03, 5e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Explored 1 nodes (0 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a593ae5ff210> in <module>
# ----> 1 resolve_model(11)
#
# <ipython-input-8-a6fd0b716147> in resolve_model(week)
#      40     regular_hours = 0
#      41     for v in m.getVars():
# ---> 42         if v.x != 0:
#      43             name = v.varName
#      44             n1 = name.split("[")[0]
#
# var.pxi in gurobipy.Var.__getattr__()
#
# var.pxi in gurobipy.Var.getAttr()
#
# AttributeError: b"Unable to retrieve attribute 'x'"

# %%
resolve_model(12)
# Out:
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 45 columns
# Presolve time: 0.01s
# Presolved: 75 rows, 50 columns, 190 nonzeros
# Variable types: 40 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 8.216657e+01, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   82.16657    0    6          -   82.16657      -     -    0s
# H    0     0                     102.8144911   82.16657  20.1%     -    0s
# H    0     0                      92.3318903   82.16657  11.0%     -    0s
#      0     0     cutoff    0        92.33189   92.33189  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#   Implied bound: 3
#   MIR: 1
#
# Explored 1 nodes (30 simplex iterations) in 0.11 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 92.3319 102.814
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.233189033189e+01, best bound 9.233189033189e+01, gap 0.0000%
# regular[Machine1_Part4] 110.256
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part2] 41.3333
# regular[Machine4_Part3] 58.6667
# regular[Machine5_Part5] 93.3333
# overtime[Machine2_Part1] 32.8571
# overtime[Machine3_Part2] 11.4747
# overtime[Machine4_Part3] 48
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# Obj: 92.3319
# total cost1: 73008.8
# regular hours: 591.59
